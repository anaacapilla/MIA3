# %% [markdown]
# <a href="https://colab.research.google.com/github/anaacapilla/MIA3/blob/main/dnn_mnist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Entrenamiento de un Perceptrón Multi-Capa con datos de dígitos (MNIST)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dense, BatchNormalization, Dropout
import matplotlib.pyplot as plt
tf.random.set_seed(42)

# %% [markdown]
# ## Carga de los datos
# #### Tamaño del conjunto de entrenamiento y de test

# %%
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()

print(' -Entradas Entrenamiento:', X_train.shape)
print(' -Salidas Entrenamiento:', y_train.shape)
print(' -Entradas Test:', X_test.shape)
print(' -Salidas Test:', y_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step
#  -Entradas Entrenamiento: (60000, 28, 28)
#  -Salidas Entrenamiento: (60000,)
#  -Entradas Test: (10000, 28, 28)
#  -Salidas Test: (10000,)

# %% [markdown]
# #### Visualización de las entradas

# %%
n_img_show = 3

# Plot images
plt.figure(figsize=(16,10))
for i in range(n_img_show):
    plt.subplot(1, n_img_show, i+1)
    plt.imshow(X_train[i], cmap='gray')
    plt.colorbar(fraction=0.046)
    plt.axis('off');

print(f'Valores de salida correspondientes a las imágenes de entrada {y_train[0:n_img_show]}')
# Out:
# Valores de salida correspondientes a las imágenes de entrada [5 0 4]

# %% [markdown]
# ## Preparación de los datos
# #### Normalización

# %%
# Normalizamos a valores entre 0 y 1
X_train = X_train.astype('float32')/255
X_test = X_test.astype('float32')/255

plt.figure(figsize=(16,10))
for i in range(n_img_show):
    plt.subplot(1, n_img_show, i+1)
    plt.imshow(X_train[i], cmap='gray')
    plt.colorbar(fraction=0.046)
    plt.axis('off');

# %% [markdown]
# #### Reajuste del tamaño de la entrada y la salida

# %% [markdown]
# Aquí vamos a reshapear nuestras imágenes, en vez de tener cuadrículas de 28x28 tendremos arrays de 1x784.
#
# Esto lo hacemos de vez para todas las muestras con el reshape indicando que tendremos 60000 muestras pero en vez de ser (60000,28,28) serán (60000,784).
#
# En la imagen, cada fila es una imagen de verdad, ya convertida a array de una dim.

# %%
x_shape = X_train.shape
X_train = X_train.reshape(x_shape[0], x_shape[1]*x_shape[2])
X_test = X_test.reshape(len(X_test), x_shape[1]*x_shape[2])
y_train = y_train[:, None]
y_test = y_test[:, None]

# Dibujar la nueva entrada
plt.figure(figsize=(20, 70))
plt.imshow(X_train[0:100], cmap='gray')
plt.xlabel('# Pixeles')
plt.ylabel('# Imágenes')
plt.colorbar(fraction=0.006);

# %% [markdown]
# ## Definición del modelo
# Crea un modelo con las siguientes capas:
# 1. Capa de entrada con tantas entradas como número de píxeles (728)
# 2. Capa oculta con 256 neuronas
# 3. Capa oculta con 128 neuronas
# 4. Capa oculta con 64 neuronas
# 5. Capa oculta con 32 neuronas
# 6. Capa de salidad con tantas neuronas como salidas (10)
#
# Todas las capas usan función de activación relu (menos la de salida). ¿Qué función de activación hay que poner a la salida?

# %%
# Algunos hiper-parámetros
lr = .001
batch_size = 512
n_epochs = 35
optimizer = tf.keras.optimizers.Adam(learning_rate=lr)

# Crear modelo
model = tf.keras.models.Sequential([
     tf.keras.layers.Dense(256, activation ="relu", input_shape=(X_train.shape[1],)),
     tf.keras.layers.Dense(128, activation ="relu"),
     tf.keras.layers.Dense(64, activation ="relu"),
     tf.keras.layers.Dense(32, activation ="relu"),
     tf.keras.layers.Dense(10, activation = "softmax")
])

# Visualizar arquitectura y dimensiones
model.summary()

# Compilamos el modelo: ¿Qué función de coste hay que utilizar?
model.compile(loss='sparse_categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_42 (Dense)            (None, 256)               200960
#
#  dense_43 (Dense)            (None, 128)               32896
#
#  dense_44 (Dense)            (None, 64)                8256
#
#  dense_45 (Dense)            (None, 32)                2080
#
#  dense_46 (Dense)            (None, 10)                330
#
# =================================================================
# Total params: 244,522
# Trainable params: 244,522
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Entrenamiento del modelo

# %%
hist = model.fit(X_train, 
                 y_train, 
                 batch_size=batch_size, 
                 epochs=n_epochs, 
                 verbose=1, 
                 shuffle=True,
                 validation_data=(X_test, y_test))
# Out:
# Epoch 1/35
# 118/118 [==============================] - 3s 18ms/step - loss: 0.5182 - accuracy: 0.8475 - val_loss: 0.2009 - val_accuracy: 0.9410
# Epoch 2/35
# 118/118 [==============================] - 2s 17ms/step - loss: 0.1635 - accuracy: 0.9521 - val_loss: 0.1330 - val_accuracy: 0.9608
# Epoch 3/35
# 118/118 [==============================] - 2s 17ms/step - loss: 0.1133 - accuracy: 0.9665 - val_loss: 0.1071 - val_accuracy: 0.9653
# Epoch 4/35
# 118/118 [==============================] - 2s 17ms/step - loss: 0.0825 - accuracy: 0.9755 - val_loss: 0.0970 - val_accuracy: 0.9721
# Epoch 5/35
# 118/118 [==============================] - 2s 17ms/step - loss: 0.0665 - accuracy: 0.9794 - val_loss: 0.0889 - val_accuracy: 0.9725
# Epoch 6/35
# 118/118 [==============================] - 2s 17ms/step - loss: 0.0539 - accuracy: 0.9840 - val_loss: 0.0791 - val_accuracy: 0.9770
# Epoch 7/35
# 118/118 [==============================] - 2s 17ms/step - loss: 0.0400 - accuracy: 0.9880 - val_loss: 0.0828 - val_accuracy: 0.9747
# Epoch 8/35
# 118/118 [==============================] - 2s 17ms/step - loss: 0.0341 - accuracy: 0.9895 - val_loss: 0.0788 - val_accuracy: 0.9771
# Epoch 9/35
# 118/118 [==============================] - 2s 17ms/step - loss: 0.0259 - accuracy: 0.9922 - val_loss: 0.0787 - val_accuracy: 0.9782
# Epoch 10/35
# 118/118 [==============================] - 2s 18ms/step - loss: 0.0214 - accuracy: 0.9934 - val_loss: 0.0826 - val_accuracy: 0.9756
# Epoch 11/35
# 118/118 [==============================] - 2s 17ms/step - loss: 0.0182 - accuracy: 0.9946 - val_loss: 0.0772 - val_accuracy: 0.9796
# Epoch 12/35
# 118/118 [==============================] - 2s 17ms/step - loss: 0.0172 - accuracy: 0.9947 - val_loss: 0.0799 - val_accuracy: 0.9791
# Epoch 13/35
# 118/118 [==============================] - 2s 17ms/step - loss: 0.0112 - accuracy: 0.9970 - val_loss: 0.0791 - val_accuracy: 0.9797
# Epoch 14/35
# 118/118 [==============================] - 2s 17ms/step - loss: 0.0101 - accuracy: 0.9970 - val_loss: 0.0966 - val_accuracy: 0.9765
# Epoch 15/35
# 118/118 [==============================] - 2s 17ms/step - loss: 0.0122 - accuracy: 0.9963 - val_loss: 0.0905 - val_accuracy: 0.9785
# Epoch 16/35
# 118/118 [==============================] - 2s 17ms/step - loss: 0.0074 - accuracy: 0.9980 - val_loss: 0.0947 - val_accuracy: 0.9780
# Epoch 17/35
# 118/118 [==============================] - 2s 17ms/step - loss: 0.0080 - accuracy: 0.9976 - val_loss: 0.0925 - val_accuracy: 0.9783
# Epoch 18/35
# 118/118 [==============================] - 2s 17ms/step - loss: 0.0127 - accuracy: 0.9957 - val_loss: 0.1044 - val_accuracy: 0.9739
# Epoch 19/35
# 118/118 [==============================] - 2s 17ms/step - loss: 0.0081 - accuracy: 0.9975 - val_loss: 0.0913 - val_accuracy: 0.9806
# Epoch 20/35
# 118/118 [==============================] - 2s 17ms/step - loss: 0.0074 - accuracy: 0.9976 - val_loss: 0.0935 - val_accuracy: 0.9783
# Epoch 21/35
# 118/118 [==============================] - 2s 17ms/step - loss: 0.0032 - accuracy: 0.9992 - val_loss: 0.0948 - val_accuracy: 0.9801
# Epoch 22/35
# 118/118 [==============================] - 2s 17ms/step - loss: 0.0032 - accuracy: 0.9991 - val_loss: 0.0991 - val_accuracy: 0.9800
# Epoch 23/35
# 118/118 [==============================] - 2s 17ms/step - loss: 0.0031 - accuracy: 0.9991 - val_loss: 0.1173 - val_accuracy: 0.9763
# Epoch 24/35
# 118/118 [==============================] - 2s 17ms/step - loss: 0.0142 - accuracy: 0.9953 - val_loss: 0.1068 - val_accuracy: 0.9751
# Epoch 25/35
# 118/118 [==============================] - 2s 17ms/step - loss: 0.0101 - accuracy: 0.9967 - val_loss: 0.0972 - val_accuracy: 0.9793
# Epoch 26/35
# 118/118 [==============================] - 2s 17ms/step - loss: 0.0071 - accuracy: 0.9976 - val_loss: 0.1082 - val_accuracy: 0.9773
# Epoch 27/35
# 118/118 [==============================] - 2s 17ms/step - loss: 0.0036 - accuracy: 0.9990 - val_loss: 0.1056 - val_accuracy: 0.9804
# Epoch 28/35
# 118/118 [==============================] - 2s 17ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.0882 - val_accuracy: 0.9826
# Epoch 29/35
# 118/118 [==============================] - 2s 17ms/step - loss: 3.8953e-04 - accuracy: 1.0000 - val_loss: 0.0932 - val_accuracy: 0.9828
# Epoch 30/35
# 118/118 [==============================] - 2s 17ms/step - loss: 1.7033e-04 - accuracy: 1.0000 - val_loss: 0.0939 - val_accuracy: 0.9827
# Epoch 31/35
# 118/118 [==============================] - 2s 17ms/step - loss: 1.1858e-04 - accuracy: 1.0000 - val_loss: 0.0959 - val_accuracy: 0.9826
# Epoch 32/35
# 118/118 [==============================] - 2s 17ms/step - loss: 9.8031e-05 - accuracy: 1.0000 - val_loss: 0.0963 - val_accuracy: 0.9829
# Epoch 33/35
# 118/118 [==============================] - 2s 17ms/step - loss: 8.5054e-05 - accuracy: 1.0000 - val_loss: 0.0979 - val_accuracy: 0.9825
# Epoch 34/35
# 118/118 [==============================] - 2s 17ms/step - loss: 7.7979e-05 - accuracy: 1.0000 - val_loss: 0.0988 - val_accuracy: 0.9827
# Epoch 35/35
# 118/118 [==============================] - 2s 17ms/step - loss: 6.8032e-05 - accuracy: 1.0000 - val_loss: 0.0998 - val_accuracy: 0.9823

# %% [markdown]
# ### Dibujar las curvas de entrenamiento/validación

# %%
def plot_curves(history):
  plt.figure()
  plt.xlabel('Épocas')
  plt.ylabel('Error')
  plt.plot(history['loss'])
  plt.plot(history['val_loss'])
  plt.legend(['Entrenamiento', 'Validación'])

  plt.figure()
  plt.xlabel('Épocas')
  plt.ylabel('Accuracy')
  plt.plot(history['accuracy'])
  plt.plot(history['val_accuracy'])
  plt.legend(['Entrenamiento', 'Validación'], loc='lower right');

plot_curves(hist.history)

# %% [markdown]
# ### Visualización de los pesos

# %%
def plot_weights(model):
  layers = [l for l in model.layers if l.name.startswith('dense')]
  n_img_show = len(layers)
  plt.figure(figsize=(30, 11))
  cnt = 1
  for layer in layers:
      plt.subplot(1, n_img_show, cnt)
      plt.imshow(layer.get_weights()[0])
      plt.title(f'Pesos capa {cnt}')
      plt.colorbar(fraction=0.07)
      cnt += 1

def plot_weights_hist(model):
  layers = [l for l in model.layers if l.name.startswith('dense')]
  n_img_show = len(layers)
  plt.figure(figsize=(30, 5))
  cnt = 1
  for layer in layers:
    if layer.name.startswith('dense'):
      plt.subplot(1, n_img_show, cnt)
      plt.hist(layer.get_weights()[0].flatten(), bins=30)
      plt.title(f'Pesos capa {cnt}')
      mean = np.mean(layer.get_weights()[0])
      std = np.std(layer.get_weights()[0])
      plt.xlabel(f'Valores de los pesos. Media: {mean:.3f} +- {std:.3f}')
      plt.ylabel('cuenta')
      cnt +=1

plot_weights(model)
plot_weights_hist(model)

# %% [markdown]
# ## Regularización del modelo con L2
# Crea un modelo nuevo exactamente igual que el anterior y añade regularización L2 en todas las capas (menos en la de salida, como es obvio). Prueba distintos valores (0.1, 0.01 y 0.001) y observa cual es el comportamiento.

# %%
from tensorflow.keras import regularizers

# %%
tf.keras.backend.clear_session()
n_epochs = 50

model_with_l2 = tf.keras.models.Sequential([
     tf.keras.layers.Dense(256, activation ="relu", input_shape = (X_train.shape[1],),kernel_regularizer=regularizers.l2(0.01)),
     tf.keras.layers.Dense(128, activation ="relu", kernel_regularizer=regularizers.l2(0.01)),
     tf.keras.layers.Dense(64, activation ="relu", kernel_regularizer=regularizers.l2(0.01)),
     tf.keras.layers.Dense(32, activation ="relu", kernel_regularizer=regularizers.l2(0.01)),
     tf.keras.layers.Dense(10, activation = "softmax")
])

# Compilamos el modelo
model_with_l2.compile(loss='sparse_categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])

# Entrenamos
hist_l2 = model_with_l2.fit(X_train, 
                         y_train, 
                         batch_size=batch_size, 
                         epochs=n_epochs,
                         verbose=1,
                         shuffle=True, 
                         validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 118/118 [==============================] - 3s 19ms/step - loss: 1.7471 - accuracy: 0.8540 - val_loss: 0.9249 - val_accuracy: 0.9073
# Epoch 2/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.8272 - accuracy: 0.9215 - val_loss: 0.7580 - val_accuracy: 0.9248
# Epoch 3/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.7235 - accuracy: 0.9304 - val_loss: 0.6719 - val_accuracy: 0.9377
# Epoch 4/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.6638 - accuracy: 0.9364 - val_loss: 0.7132 - val_accuracy: 0.9088
# Epoch 5/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.6337 - accuracy: 0.9392 - val_loss: 0.6058 - val_accuracy: 0.9420
# Epoch 6/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.6017 - accuracy: 0.9434 - val_loss: 0.6148 - val_accuracy: 0.9293
# Epoch 7/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.5857 - accuracy: 0.9432 - val_loss: 0.5690 - val_accuracy: 0.9471
# Epoch 8/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.5647 - accuracy: 0.9464 - val_loss: 0.5872 - val_accuracy: 0.9384
# Epoch 9/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.5574 - accuracy: 0.9459 - val_loss: 0.5414 - val_accuracy: 0.9451
# Epoch 10/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.5415 - accuracy: 0.9477 - val_loss: 0.5303 - val_accuracy: 0.9497
# Epoch 11/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.5301 - accuracy: 0.9487 - val_loss: 0.5365 - val_accuracy: 0.9420
# Epoch 12/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.5209 - accuracy: 0.9503 - val_loss: 0.5158 - val_accuracy: 0.9511
# Epoch 13/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.5079 - accuracy: 0.9520 - val_loss: 0.4955 - val_accuracy: 0.9522
# Epoch 14/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.5007 - accuracy: 0.9522 - val_loss: 0.5228 - val_accuracy: 0.9419
# Epoch 15/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.4968 - accuracy: 0.9521 - val_loss: 0.4880 - val_accuracy: 0.9528
# Epoch 16/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.4840 - accuracy: 0.9543 - val_loss: 0.4934 - val_accuracy: 0.9528
# Epoch 17/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.4841 - accuracy: 0.9543 - val_loss: 0.4751 - val_accuracy: 0.9535
# Epoch 18/50
# 118/118 [==============================] - 2s 19ms/step - loss: 0.4733 - accuracy: 0.9553 - val_loss: 0.4687 - val_accuracy: 0.9555
# Epoch 19/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.4697 - accuracy: 0.9556 - val_loss: 0.4623 - val_accuracy: 0.9572
# Epoch 20/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.4640 - accuracy: 0.9570 - val_loss: 0.4701 - val_accuracy: 0.9514
# Epoch 21/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.4601 - accuracy: 0.9567 - val_loss: 0.4511 - val_accuracy: 0.9581
# Epoch 22/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.4536 - accuracy: 0.9572 - val_loss: 0.4465 - val_accuracy: 0.9575
# Epoch 23/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.4501 - accuracy: 0.9576 - val_loss: 0.4427 - val_accuracy: 0.9579
# Epoch 24/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.4447 - accuracy: 0.9582 - val_loss: 0.4383 - val_accuracy: 0.9573
# Epoch 25/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.4415 - accuracy: 0.9586 - val_loss: 0.4448 - val_accuracy: 0.9547
# Epoch 26/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.4371 - accuracy: 0.9591 - val_loss: 0.4498 - val_accuracy: 0.9508
# Epoch 27/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.4353 - accuracy: 0.9589 - val_loss: 0.4323 - val_accuracy: 0.9570
# Epoch 28/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.4291 - accuracy: 0.9602 - val_loss: 0.4260 - val_accuracy: 0.9588
# Epoch 29/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.4257 - accuracy: 0.9608 - val_loss: 0.4432 - val_accuracy: 0.9517
# Epoch 30/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.4248 - accuracy: 0.9599 - val_loss: 0.4285 - val_accuracy: 0.9541
# Epoch 31/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.4224 - accuracy: 0.9598 - val_loss: 0.4225 - val_accuracy: 0.9580
# Epoch 32/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.4189 - accuracy: 0.9603 - val_loss: 0.4239 - val_accuracy: 0.9544
# Epoch 33/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.4126 - accuracy: 0.9620 - val_loss: 0.4150 - val_accuracy: 0.9608
# Epoch 34/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.4114 - accuracy: 0.9611 - val_loss: 0.4129 - val_accuracy: 0.9583
# Epoch 35/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.4119 - accuracy: 0.9610 - val_loss: 0.4148 - val_accuracy: 0.9586
# Epoch 36/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.4096 - accuracy: 0.9609 - val_loss: 0.4196 - val_accuracy: 0.9567
# Epoch 37/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.4055 - accuracy: 0.9625 - val_loss: 0.4200 - val_accuracy: 0.9553
# Epoch 38/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.4048 - accuracy: 0.9617 - val_loss: 0.4132 - val_accuracy: 0.9571
# Epoch 39/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.4052 - accuracy: 0.9606 - val_loss: 0.4034 - val_accuracy: 0.9598
# Epoch 40/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.4008 - accuracy: 0.9616 - val_loss: 0.3931 - val_accuracy: 0.9618
# Epoch 41/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.3955 - accuracy: 0.9628 - val_loss: 0.3923 - val_accuracy: 0.9623
# Epoch 42/50
# 118/118 [==============================] - 2s 19ms/step - loss: 0.3950 - accuracy: 0.9622 - val_loss: 0.4177 - val_accuracy: 0.9537
# Epoch 43/50
# 118/118 [==============================] - 2s 19ms/step - loss: 0.3913 - accuracy: 0.9630 - val_loss: 0.3925 - val_accuracy: 0.9608
# Epoch 44/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.3891 - accuracy: 0.9631 - val_loss: 0.4186 - val_accuracy: 0.9501
# Epoch 45/50
# 118/118 [==============================] - 2s 19ms/step - loss: 0.3881 - accuracy: 0.9627 - val_loss: 0.3879 - val_accuracy: 0.9614
# Epoch 46/50
# 118/118 [==============================] - 2s 19ms/step - loss: 0.3864 - accuracy: 0.9639 - val_loss: 0.4016 - val_accuracy: 0.9588
# Epoch 47/50
# 118/118 [==============================] - 2s 19ms/step - loss: 0.3880 - accuracy: 0.9621 - val_loss: 0.3888 - val_accuracy: 0.9611
# Epoch 48/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.3817 - accuracy: 0.9641 - val_loss: 0.3891 - val_accuracy: 0.9610
# Epoch 49/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.3779 - accuracy: 0.9642 - val_loss: 0.3971 - val_accuracy: 0.9576
# Epoch 50/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.3788 - accuracy: 0.9647 - val_loss: 0.3800 - val_accuracy: 0.9618

# %% [markdown]
# ### Evaluación del modelo con regularización L2

# %%
plot_curves(hist_l2.history)

# %% [markdown]
# ### Visualización de los pesos

# %%
plot_weights(model_with_l2)
plot_weights_hist(model_with_l2)

# %% [markdown]
# ## Regularización del modelo con Dropout
# Ahora crea el mismo modelo pero añade dropout. Prueba distintos valores de dropout.

# %%
tf.keras.backend.clear_session()

# Crear modelo
n_epochs = 25
model_with_dp = tf.keras.models.Sequential([
     tf.keras.layers.Dense(256, activation ="relu", input_shape=(X_train.shape[1],)),
     tf.keras.layers.Dropout(0.4),
     tf.keras.layers.Dense(128, activation ="relu"),
     tf.keras.layers.Dropout(0.4),
     tf.keras.layers.Dense(64, activation ="relu"),
     tf.keras.layers.Dropout(0.4),
     tf.keras.layers.Dense(32, activation ="relu"),
     tf.keras.layers.Dropout(0.4), 
     tf.keras.layers.Dense(10, activation = "softmax")
])

# Compilamos el modelo
model_with_dp.compile(loss='sparse_categorical_crossentropy',
                      optimizer=optimizer,
                      metrics=['accuracy'])

# Entrenamos
hist = model_with_dp.fit(X_train, 
                         y_train, 
                         batch_size=batch_size, 
                         epochs=n_epochs,
                         verbose=1, 
                         shuffle=True, 
                         validation_data=(X_test, y_test))
# Out:
# Epoch 1/25
# 118/118 [==============================] - 3s 22ms/step - loss: 0.8508 - accuracy: 0.7278 - val_loss: 0.2510 - val_accuracy: 0.9365
# Epoch 2/25
# 118/118 [==============================] - 2s 21ms/step - loss: 0.3825 - accuracy: 0.9036 - val_loss: 0.1706 - val_accuracy: 0.9553
# Epoch 3/25
# 118/118 [==============================] - 2s 21ms/step - loss: 0.3045 - accuracy: 0.9265 - val_loss: 0.1514 - val_accuracy: 0.9607
# Epoch 4/25
# 118/118 [==============================] - 2s 21ms/step - loss: 0.2657 - accuracy: 0.9364 - val_loss: 0.1446 - val_accuracy: 0.9645
# Epoch 5/25
# 118/118 [==============================] - 2s 20ms/step - loss: 0.2350 - accuracy: 0.9428 - val_loss: 0.1325 - val_accuracy: 0.9679
# Epoch 6/25
# 118/118 [==============================] - 2s 21ms/step - loss: 0.2219 - accuracy: 0.9471 - val_loss: 0.1253 - val_accuracy: 0.9695
# Epoch 7/25
# 118/118 [==============================] - 2s 21ms/step - loss: 0.1967 - accuracy: 0.9527 - val_loss: 0.1144 - val_accuracy: 0.9724
# Epoch 8/25
# 118/118 [==============================] - 2s 20ms/step - loss: 0.1928 - accuracy: 0.9535 - val_loss: 0.1187 - val_accuracy: 0.9726
# Epoch 9/25
# 118/118 [==============================] - 2s 20ms/step - loss: 0.1827 - accuracy: 0.9562 - val_loss: 0.1169 - val_accuracy: 0.9726
# Epoch 10/25
# 118/118 [==============================] - 2s 21ms/step - loss: 0.1759 - accuracy: 0.9577 - val_loss: 0.1136 - val_accuracy: 0.9743
# Epoch 11/25
# 118/118 [==============================] - 2s 20ms/step - loss: 0.1633 - accuracy: 0.9607 - val_loss: 0.1135 - val_accuracy: 0.9758
# Epoch 12/25
# 118/118 [==============================] - 2s 20ms/step - loss: 0.1549 - accuracy: 0.9628 - val_loss: 0.1109 - val_accuracy: 0.9751
# Epoch 13/25
# 118/118 [==============================] - 2s 20ms/step - loss: 0.1548 - accuracy: 0.9632 - val_loss: 0.1074 - val_accuracy: 0.9764
# Epoch 14/25
# 118/118 [==============================] - 2s 20ms/step - loss: 0.1470 - accuracy: 0.9657 - val_loss: 0.1127 - val_accuracy: 0.9752
# Epoch 15/25
# 118/118 [==============================] - 2s 21ms/step - loss: 0.1445 - accuracy: 0.9651 - val_loss: 0.1141 - val_accuracy: 0.9763
# Epoch 16/25
# 118/118 [==============================] - 2s 21ms/step - loss: 0.1393 - accuracy: 0.9667 - val_loss: 0.1104 - val_accuracy: 0.9764
# Epoch 17/25
# 118/118 [==============================] - 2s 21ms/step - loss: 0.1321 - accuracy: 0.9681 - val_loss: 0.1104 - val_accuracy: 0.9764
# Epoch 18/25
# 118/118 [==============================] - 2s 21ms/step - loss: 0.1340 - accuracy: 0.9670 - val_loss: 0.1094 - val_accuracy: 0.9769
# Epoch 19/25
# 118/118 [==============================] - 2s 21ms/step - loss: 0.1315 - accuracy: 0.9678 - val_loss: 0.1059 - val_accuracy: 0.9770
# Epoch 20/25
# 118/118 [==============================] - 2s 21ms/step - loss: 0.1243 - accuracy: 0.9694 - val_loss: 0.1145 - val_accuracy: 0.9764
# Epoch 21/25
# 118/118 [==============================] - 2s 21ms/step - loss: 0.1217 - accuracy: 0.9702 - val_loss: 0.1147 - val_accuracy: 0.9762
# Epoch 22/25
# 118/118 [==============================] - 2s 21ms/step - loss: 0.1167 - accuracy: 0.9714 - val_loss: 0.1095 - val_accuracy: 0.9769
# Epoch 23/25
# 118/118 [==============================] - 2s 20ms/step - loss: 0.1176 - accuracy: 0.9724 - val_loss: 0.1132 - val_accuracy: 0.9770
# Epoch 24/25
# 118/118 [==============================] - 2s 20ms/step - loss: 0.1154 - accuracy: 0.9730 - val_loss: 0.1103 - val_accuracy: 0.9771
# Epoch 25/25
# 118/118 [==============================] - 2s 21ms/step - loss: 0.1118 - accuracy: 0.9730 - val_loss: 0.1169 - val_accuracy: 0.9775

# %% [markdown]
# ### Evaluación del modelo con Dropout

# %%
# Plots
plot_curves(hist.history)
# plot_weights(model_with_dp)
plot_weights_hist(model_with_dp)
